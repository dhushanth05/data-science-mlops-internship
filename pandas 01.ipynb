# %%
import pandas as pd

df= pd.read_csv('pokemon_data.csv')
print(df.tail(5))
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
print(df.head(10))
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %%
df_xlsx = pd.read_excel('pokemon_data.xlsx')
print(df_xlsx)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df_txt = pd.read_csv('pokemon_data.txt', delimiter='\t')
print(df_txt)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
print(df.columns)

print(df[['Name','Attack', 'Defense']].head(100))

print(df.iloc[0:5])

print(df.iloc[2,5])
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')
#                      Name  Attack  Defense
# 0               Bulbasaur      49       49
# 1                 Ivysaur      62       63
# 2                Venusaur      82       83
# 3   VenusaurMega Venusaur     100      123
# 4              Charmander      52       43
# ..                    ...     ...      ...
# 95                 Grimer      80       50
# 96                    Muk     105       75
# 97               Shellder      65      100
# 98               Cloyster      95      180
# 99                 Gastly      35       30
#
# [100 rows x 3 columns]
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# ...

# %%
for index, row in df.iterrows():
    print(index, row['Name'])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# ...

# %%
df.loc[df['Type 1'] == "Fire"]
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
df.loc[df['Type 2'] == "Dragon"]
# Out:
#        #                       Name    Type 1  Type 2   HP  Attack  Defense  \
# 7      6  CharizardMega Charizard X      Fire  Dragon   78     130      111
# 196  181      AmpharosMega Ampharos  Electric  Dragon   90      95      105
# 249  230                    Kingdra     Water  Dragon   75      95       95
# 275  254      SceptileMega Sceptile     Grass  Dragon   70     110       75
# 360  329                    Vibrava    Ground  Dragon   50      70       50
# 361  330                     Flygon    Ground  Dragon   80     100       80
# 540  483                     Dialga     Steel  Dragon  100     120      120
# 541  484                     Palkia     Water  Dragon   90     120      100
# 544  487      GiratinaAltered Forme     Ghost  Dragon  150     100      120
# 545  487       GiratinaOrigin Forme     Ghost  Dragon  150     120      100
# 694  633                      Deino      Dark  Dragon   52      65       50
# ...

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values('Name', ascending =True)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Type 1','HP'], ascending =True)
# Out:
#        #       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292   Shedinja    Bug   Ghost    1      90       45       30       30
# 230  213    Shuckle    Bug    Rock   20      10      230       10      230
# 462  415     Combee    Bug  Flying   30      30       42       30       42
# 603  543   Venipede    Bug  Poison   30      45       59       30       39
# 314  290    Nincada    Bug  Ground   31      45       90       30       30
# ..   ...        ...    ...     ...  ...     ...      ...      ...      ...
# 142  131     Lapras  Water     Ice  130      85       80       85       95
# 145  134   Vaporeon  Water     NaN  130      65       60      110       95
# 350  320    Wailmer  Water     NaN  130      70       35       70       35
# 655  594  Alomomola  Water     NaN  165      75       80       40       45
# 351  321    Wailord  Water     NaN  170      90       45       90       45
#
#      Speed  Generation  Legendary
# ...

# %%
df['Total'] = df['Attack'] = df['Defense']
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      63       63       80
# 2  3               Venusaur  Grass  Poison  80      83       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     123      123      122
# 4  4             Charmander   Fire     NaN  39      43       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False     49
# 1       80     60           1      False     63
# 2      100     80           1      False     83
# 3      120     80           1      False    123
# 4       50     65           1      False     43

# %%
df = df.drop(columns=['Total'])

# %%
df.head(4)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      63       63       80
# 2  3               Venusaur  Grass  Poison  80      83       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     123      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
df['Total'] = df.iloc[: , 4:10].sum(axis=1)
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      63       63       80
# 2  3               Venusaur  Grass  Poison  80      83       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     123      123      122
# 4  4             Charmander   Fire     NaN  39      43       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    406
# 2      100     80           1      False    526
# 3      120     80           1      False    648
# 4       50     65           1      False    300

# %%
cols = list(df.columns)
df = df[cols[0:4] + [cols[12]] + cols[4:12]]

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    406  60      63       63
# 2  3               Venusaur  Grass  Poison    526  80      83       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    648  80     123      123
# 4  4             Charmander   Fire     NaN    300  39      43       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.to_csv('new.csv',index=False)

# %%
df.to_csv('new.txt',index=False,sep='\t')

# %%
new_df = df.loc[(df['Type 1'] == "Fire") & (df['Type 2'] == "Dragon") & (df['HP'] > 70)]

# %%
new_df
# Out:
#    index  #                       Name Type 1  Type 2  Total  HP  Attack  \
# 7      7  6  CharizardMega Charizard X   Fire  Dragon    615  78     111
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 7      111      130       85    100           1      False

# %%
df.loc[~df['Name'].str.contains('Mega')]
# Out:
#      level_0  index    #                 Name   Type 1  Type 2  Total   HP  \
# 0          0      0    1            Bulbasaur    Grass  Poison    318   45
# 1          1      1    2              Ivysaur    Grass  Poison    406   60
# 2          2      2    3             Venusaur    Grass  Poison    526   80
# 4          4      4    4           Charmander     Fire     NaN    300   39
# 5          5      5    5           Charmeleon     Fire     NaN    399   58
# ..       ...    ...  ...                  ...      ...     ...    ...  ...
# 794      794    794  718     Zygarde50% Forme   Dragon  Ground    621  108
# 795      795    795  719              Diancie     Rock   Fairy    650   50
# 797      797    797  720  HoopaHoopa Confined  Psychic   Ghost    550   80
# 798      798    798  720   HoopaHoopa Unbound  Psychic    Dark    580   80
# 799      799    799  721            Volcanion     Fire   Water    610   80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
import re
df.loc[df['Type 1'].str.contains('Fire|grass', flags=re.I)]
# Out:
#      level_0  index    #                   Name Type 1  Type 2  Total   HP  \
# 0          0      0    1              Bulbasaur  Grass  Poison    318   45
# 1          1      1    2                Ivysaur  Grass  Poison    406   60
# 2          2      2    3               Venusaur  Grass  Poison    526   80
# 3          3      3    3  VenusaurMega Venusaur  Grass  Poison    648   80
# 4          4      4    4             Charmander   Fire     NaN    300   39
# ..       ...    ...  ...                    ...    ...     ...    ...  ...
# 735      735    735  667                 Litleo   Fire  Normal    377   62
# 736      736    736  668                 Pyroar   Fire  Normal    511   86
# 740      740    740  672                 Skiddo  Grass     NaN    333   66
# 741      741    741  673                 Gogoat  Grass     NaN    493  123
# 799      799    799  721              Volcanion   Fire   Water    610   80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.loc[df['Name'].str.contains('^pi[a-z]*', flags=re.I)]
# Out:
#      level_0  index    #                 Name    Type 1    Type 2  Total   HP  \
# 20        20     20   16               Pidgey    Normal    Flying    246   40
# 21        21     21   17            Pidgeotto    Normal    Flying    344   63
# 22        22     22   18              Pidgeot    Normal    Flying    474   83
# 23        23     23   18  PidgeotMega Pidgeot    Normal    Flying    579   83
# 30        30     30   25              Pikachu  Electric       NaN    305   35
# 136      136    136  127               Pinsir       Bug       NaN    475   65
# 137      137    137  127    PinsirMega Pinsir       Bug    Flying    565   65
# 186      186    186  172                Pichu  Electric       NaN    180   20
# 219      219    219  204               Pineco       Bug       NaN    315   50
# 239      239    239  221            Piloswine       Ice    Ground    430  100
# 438      438    438  393               Piplup     Water       NaN    316   53
# ...

# %%
df.loc[df['Type 1'] == "fire" , 'Type 1'] = "flame"

df
# Out:
#      level_0  index    #                   Name   Type 1  Type 2  Total  HP  \
# 0          0      0    1              Bulbasaur    Grass  Poison    318  45
# 1          1      1    2                Ivysaur    Grass  Poison    406  60
# 2          2      2    3               Venusaur    Grass  Poison    526  80
# 3          3      3    3  VenusaurMega Venusaur    Grass  Poison    648  80
# 4          4      4    4             Charmander    flame     NaN    300  39
# ..       ...    ...  ...                    ...      ...     ...    ...  ..
# 795      795    795  719                Diancie     Rock   Fairy    650  50
# 796      796    796  719    DiancieMega Diancie     Rock   Fairy    650  50
# 797      797    797  720    HoopaHoopa Confined  Psychic   Ghost    550  80
# 798      798    798  720     HoopaHoopa Unbound  Psychic    Dark    580  80
# 799      799    799  721              Volcanion    flame   Water    610  80
#
# ...

# %%
df.loc[df['Type 2'] == "Poison" , 'Legendary'] = True
df
# Out:
#      level_0  index    #                   Name   Type 1  Type 2  Total  HP  \
# 0          0      0    1              Bulbasaur    Grass  Poison    318  45
# 1          1      1    2                Ivysaur    Grass  Poison    406  60
# 2          2      2    3               Venusaur    Grass  Poison    526  80
# 3          3      3    3  VenusaurMega Venusaur    Grass  Poison    648  80
# 4          4      4    4             Charmander    flame     NaN    300  39
# ..       ...    ...  ...                    ...      ...     ...    ...  ..
# 795      795    795  719                Diancie     Rock   Fairy    650  50
# 796      796    796  719    DiancieMega Diancie     Rock   Fairy    650  50
# 797      797    797  720    HoopaHoopa Confined  Psychic   Ghost    550  80
# 798      798    798  720     HoopaHoopa Unbound  Psychic    Dark    580  80
# 799      799    799  721              Volcanion    flame   Water    610  80
#
# ...

# %%
df.loc[df['Total'] > 500 , ['Generation',   'Legendary'] ]= ['test 1','testagain']
df
# Out:
# C:\Users\Dhushanth S\AppData\Local\Temp\ipykernel_12540\2150651798.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'test 1' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Total'] > 500 , ['Generation',   'Legendary'] ]= ['test 1','testagain']
# C:\Users\Dhushanth S\AppData\Local\Temp\ipykernel_12540\2150651798.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'testagain' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   df.loc[df['Total'] > 500 , ['Generation',   'Legendary'] ]= ['test 1','testagain']
#      level_0  index    #                   Name   Type 1  Type 2  Total  HP  \
# 0          0      0    1              Bulbasaur    Grass  Poison    318  45
# ...

# %%
df.groupby(['Type 1']).mean(numeric_only=True).sort_values('Speed', ascending=False)
# Out:
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Flying    677.750000  70.750000   78.750000   66.250000  94.250000  72.500000
# Electric  363.500000  59.795455   69.090909   66.295455  90.022727  73.704545
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Psychic   380.807018  70.631579   71.456140   67.684211  98.403509  86.280702
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# Fire      327.403846  69.903846   84.769231   67.769231  88.980769  72.211538
# Normal    319.173469  77.275510   73.469388   59.846939  55.816327  63.724490
# Fighting  363.851852  69.851852   96.777778   65.925926  53.111111  64.703704
# Water     303.089286  72.062500   74.151786   72.946429  74.812500  70.517857
# Ghost     486.500000  64.437500   73.781250   81.187500  79.343750  76.468750
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# ...

# %%
df.groupby(['Type 1']).sum(numeric_only=True).sort_values('Attack', ascending=False)
# Out:
#               #    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Type 1
# Water     33946  8071    8305     8170     8379     7898   7388         320
# Normal    31279  7573    7200     5865     5470     6245   7012         299
# Grass     24141  4709    5125     4956     5425     4930   4335         235
# Bug       23080  3925    4897     4880     3717     4471   4256         222
# Fire      17025  3635    4408     3524     4627     3755   3871         167
# Rock      17280  2876    4086     4435     2787     3321   2460         152
# Psychic   21706  4026    4073     3858     5609     4918   4645         193
# Dragon    15180  2666    3588     2764     3099     2843   2657         124
# Ground    11401  2361    3064     2715     1807     2008   2045         101
# Electric  15994  2631    3040     2917     3961     3243   3718         144
# Dark      14302  2071    2740     2177     2314     2155   2361         125
# ...

# %%
df['count'] = 1
df.groupby(['Type 1']).count()['count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %%
df['count'] = 1
df.groupby(['Type 1', 'Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64
