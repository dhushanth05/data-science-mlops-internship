# %%
import pandas as pd

df = pd.read_csv('malaysia_aml_fraud_anomaly_transactions.csv')
df
# Out:
#      transaction_id transaction_datetime customer_id account_id  customer_age  \
# 0      TXN202600000  2026-01-18 19:42:00    CUST1322   ACC11122            37
# 1      TXN202600001  2026-04-14 11:54:00    CUST1270   ACC10255            18
# 2      TXN202600002  2026-03-07 20:12:00    CUST1349   ACC10060            27
# 3      TXN202600003  2026-07-23 10:03:00    CUST1139   ACC10092            60
# 4      TXN202600004  2026-05-30 18:36:00    CUST1215   ACC10744            26
# ...             ...                  ...         ...        ...           ...
# 1495   TXN202601495  2026-06-11 06:08:00    CUST1334   ACC10080            33
# 1496   TXN202601496  2026-03-01 16:58:00    CUST1109   ACC10478            42
# 1497   TXN202601497  2026-04-15 14:00:00    CUST1035   ACC10148            50
# 1498   TXN202601498  2026-05-02 02:09:00    CUST1271   ACC11013            26
# 1499   TXN202601499  2026-06-15 17:19:00    CUST1154   ACC10834            32
#
# ...

# %%
display(df.head(5))
display(df.tail(5))
# Out:
#   transaction_id transaction_datetime customer_id account_id  customer_age  \
# 0   TXN202600000  2026-01-18 19:42:00    CUST1322   ACC11122            37
# 1   TXN202600001  2026-04-14 11:54:00    CUST1270   ACC10255            18
# 2   TXN202600002  2026-03-07 20:12:00    CUST1349   ACC10060            27
# 3   TXN202600003  2026-07-23 10:03:00    CUST1139   ACC10092            60
# 4   TXN202600004  2026-05-30 18:36:00    CUST1215   ACC10744            26
#
#     customer_segment     occupation         state          branch  \
# 0  Emerging Affluent     Unemployed  Kuala Lumpur   Bukit Bintang
# 1               Mass  Self-employed       Sarawak         Kuching
# 2               Mass        Student         Perak            Ipoh
# 3           Affluent       Salaried        Melaka  Melaka Central
# 4                SME        Retired      Selangor         Kuching
#
#    monthly_income_myr  ...  manual_red_flag_count risk_category anomaly_score  \
# ...

# %%
df.shape
# Out:
# (1500, 44)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 44 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   transaction_id                 1500 non-null   str
#  1   transaction_datetime           1500 non-null   str
#  2   customer_id                    1500 non-null   str
#  3   account_id                     1500 non-null   str
#  4   customer_age                   1500 non-null   int64
#  5   customer_segment               1500 non-null   str
#  6   occupation                     1470 non-null   str
#  7   state                          1500 non-null   str
#  8   branch                         1500 non-null   str
#  9   monthly_income_myr             1500 non-null   float64
#  10  account_age_days               1500 non-null   int64
#  11  kyc_status                     1470 non-null   str
#  12  transaction_type               1500 non-null   str
# ...

# %%
df.describe()
# Out:
#        customer_age  monthly_income_myr  account_age_days  \
# count    1500.00000         1500.000000       1500.000000
# mean       38.75600        10097.207700        690.075333
# std        11.39721        10300.168134        731.934866
# min        18.00000          300.000000          1.000000
# 25%        31.00000         3584.682500        156.750000
# 50%        38.00000         7171.035000        461.000000
# 75%        47.00000        11462.110000        968.250000
# max        76.00000        70877.670000       5227.000000
#
#        transaction_amount_myr  balance_before_myr  balance_after_myr  \
# count             1500.000000         1500.000000        1500.000000
# mean              5180.085887        16135.575880       16474.062667
# std              21755.509560        19875.770818       20788.649906
# min                105.580000          257.270000           0.000000
# 25%                787.632500         5203.152500        4377.442500
# ...

# %%
df.columns
# Out:
# Index(['transaction_id', 'transaction_datetime', 'customer_id', 'account_id',
#        'customer_age', 'customer_segment', 'occupation', 'state', 'branch',
#        'monthly_income_myr', 'account_age_days', 'kyc_status',
#        'transaction_type', 'channel', 'transaction_amount_myr',
#        'balance_before_myr', 'balance_after_myr', 'previous_30d_txn_count',
#        'previous_30d_total_amount_myr', 'merchant_category', 'device_type',
#        'ip_country', 'destination_country', 'failed_login_count_24h',
#        'round_amount_flag', 'unusual_time_flag', 'cross_border_flag',
#        'sanctioned_country_flag', 'high_risk_merchant_flag',
#        'income_mismatch_flag', 'structuring_flag', 'velocity_flag',
#        'new_account_high_value_flag', 'geo_mismatch_flag',
#        'manual_red_flag_count', 'risk_category', 'anomaly_score',
#        'anomaly_or_not', 'fraud_label', 'aml_suspicious_label',
#        'sentiment_label', 'customer_message', 'investigator_note',
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# transaction_id                    0
# transaction_datetime              0
# customer_id                       0
# account_id                        0
# customer_age                      0
# customer_segment                  0
# occupation                       30
# state                             0
# branch                            0
# monthly_income_myr                0
# account_age_days                  0
# kyc_status                       30
# transaction_type                  0
# channel                           0
# transaction_amount_myr            0
# balance_before_myr                0
# balance_after_myr                 0
# previous_30d_txn_count            0
# previous_30d_total_amount_myr     0
# merchant_category                30
# device_type                      30
# ip_country                       30
# destination_country               0
# failed_login_count_24h            0
# round_amount_flag                 0
# unusual_time_flag                 0
# ...

# %%
df[df["occupation"].isnull()]
# Out:
#      transaction_id transaction_datetime customer_id account_id  customer_age  \
# 142    TXN202600142  2026-06-28 23:39:00    CUST1133   ACC10513            52
# 183    TXN202600183  2026-05-26 10:15:00    CUST1084   ACC10982            27
# 185    TXN202600185  2026-04-11 11:54:00    CUST1325   ACC10820            31
# 276    TXN202600276  2026-05-11 03:29:00    CUST1187   ACC10463            58
# 294    TXN202600294  2026-01-15 11:30:00    CUST1216   ACC10972            51
# 483    TXN202600483  2026-01-15 11:48:00    CUST1229   ACC10256            58
# 611    TXN202600611  2026-05-14 05:32:00    CUST1186   ACC10482            39
# 630    TXN202600630  2026-03-23 08:35:00    CUST1301   ACC11154            39
# 643    TXN202600643  2026-07-24 15:04:00    CUST1213   ACC10809            49
# 664    TXN202600664  2026-01-31 11:52:00    CUST1119   ACC10755            45
# 730    TXN202600730  2026-01-31 18:46:00    CUST1320   ACC10679            43
# ...

# %%
df["occupation"] = df["occupation"].fillna("Unknown")
df["kyc_status"] = df["kyc_status"].fillna("Unknown")
df["merchant_category"] = df["merchant_category"].fillna("Unknown")
df["device_type"] = df["device_type"].fillna("Unknown")
df["ip_country"] = df["ip_country"].fillna("Unknown")
df["customer_message"] = df["customer_message"].fillna("Unknown")

# %%
df.isnull().sum()
# Out:
# transaction_id                   0
# transaction_datetime             0
# customer_id                      0
# account_id                       0
# customer_age                     0
# customer_segment                 0
# occupation                       0
# state                            0
# branch                           0
# monthly_income_myr               0
# account_age_days                 0
# kyc_status                       0
# transaction_type                 0
# channel                          0
# transaction_amount_myr           0
# balance_before_myr               0
# balance_after_myr                0
# previous_30d_txn_count           0
# previous_30d_total_amount_myr    0
# merchant_category                0
# device_type                      0
# ip_country                       0
# destination_country              0
# failed_login_count_24h           0
# round_amount_flag                0
# unusual_time_flag                0
# cross_border_flag                0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# transaction_id                       str
# transaction_datetime                 str
# customer_id                          str
# account_id                           str
# customer_age                       int64
# customer_segment                     str
# occupation                           str
# state                                str
# branch                               str
# monthly_income_myr               float64
# account_age_days                   int64
# kyc_status                           str
# transaction_type                     str
# channel                              str
# transaction_amount_myr           float64
# balance_before_myr               float64
# balance_after_myr                float64
# previous_30d_txn_count             int64
# previous_30d_total_amount_myr    float64
# merchant_category                    str
# device_type                          str
# ip_country                           str
# destination_country                  str
# ...

# %%
df["transaction_datetime"] = pd.to_datetime(df["transaction_datetime"])

# %%
df.dtypes
# Out:
# transaction_id                              str
# transaction_datetime             datetime64[us]
# customer_id                                 str
# account_id                                  str
# customer_age                              int64
# customer_segment                            str
# occupation                                  str
# state                                       str
# branch                                      str
# monthly_income_myr                      float64
# account_age_days                          int64
# kyc_status                                  str
# transaction_type                            str
# channel                                     str
# transaction_amount_myr                  float64
# balance_before_myr                      float64
# balance_after_myr                       float64
# previous_30d_txn_count                    int64
# previous_30d_total_amount_myr           float64
# merchant_category                           str
# ...

# %%
df["transaction_datetime"].isnull().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#      transaction_id transaction_datetime customer_id account_id  customer_age  \
# 0      TXN202600000  2026-01-18 19:42:00    CUST1322   ACC11122            37
# 1      TXN202600001  2026-04-14 11:54:00    CUST1270   ACC10255            18
# 2      TXN202600002  2026-03-07 20:12:00    CUST1349   ACC10060            27
# 3      TXN202600003  2026-07-23 10:03:00    CUST1139   ACC10092            60
# 4      TXN202600004  2026-05-30 18:36:00    CUST1215   ACC10744            26
# ...             ...                  ...         ...        ...           ...
# 1495   TXN202601495  2026-06-11 06:08:00    CUST1334   ACC10080            33
# 1496   TXN202601496  2026-03-01 16:58:00    CUST1109   ACC10478            42
# 1497   TXN202601497  2026-04-15 14:00:00    CUST1035   ACC10148            50
# 1498   TXN202601498  2026-05-02 02:09:00    CUST1271   ACC11013            26
# 1499   TXN202601499  2026-06-15 17:19:00    CUST1154   ACC10834            32
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["customer_segment"].unique()
# Out:
# <StringArray>
# ['Emerging Affluent', 'Mass', 'Affluent', 'SME', 'Private Banking']
# Length: 5, dtype: str

# %%
df["transaction_type"].unique()
# Out:
# <StringArray>
# [        'Local Transfer',          'Card Purchase',          'Wallet Top-up',
#            'Cash Deposit',           'Bill Payment',         'Loan Repayment',
#  'International Transfer',        'Cash Withdrawal']
# Length: 8, dtype: str

# %%
df["channel"].unique()
# Out:
# <StringArray>
# [            'Mobile App',                    'ATM', 'International Transfer',
#          'Online Banking',   'Cash Deposit Machine',                 'Branch',
#                'Card POS']
# Length: 7, dtype: str

# %%
df["risk_category"].value_counts()
# Out:
# risk_category
# Low       803
# High      405
# Medium    292
# Name: count, dtype: int64

# %%
df["transaction_type"].value_counts()
# Out:
# transaction_type
# Local Transfer            350
# Card Purchase             289
# Bill Payment              193
# Cash Deposit              179
# International Transfer    137
# Cash Withdrawal           133
# Wallet Top-up             119
# Loan Repayment            100
# Name: count, dtype: int64

# %%
df["transaction_amount_myr"].max()
# Out:
# np.float64(600425.4)

# %%
df["transaction_month"] = df["transaction_datetime"].dt.month

# %%
df
# Out:
#      transaction_id transaction_datetime customer_id account_id  customer_age  \
# 0      TXN202600000  2026-01-18 19:42:00    CUST1322   ACC11122            37
# 1      TXN202600001  2026-04-14 11:54:00    CUST1270   ACC10255            18
# 2      TXN202600002  2026-03-07 20:12:00    CUST1349   ACC10060            27
# 3      TXN202600003  2026-07-23 10:03:00    CUST1139   ACC10092            60
# 4      TXN202600004  2026-05-30 18:36:00    CUST1215   ACC10744            26
# ...             ...                  ...         ...        ...           ...
# 1495   TXN202601495  2026-06-11 06:08:00    CUST1334   ACC10080            33
# 1496   TXN202601496  2026-03-01 16:58:00    CUST1109   ACC10478            42
# 1497   TXN202601497  2026-04-15 14:00:00    CUST1035   ACC10148            50
# 1498   TXN202601498  2026-05-02 02:09:00    CUST1271   ACC11013            26
# 1499   TXN202601499  2026-06-15 17:19:00    CUST1154   ACC10834            32
#
# ...

# %%
df.groupby("transaction_type")["transaction_amount_myr"].mean()
# Out:
# transaction_type
# Bill Payment              3873.200311
# Card Purchase             2556.979862
# Cash Deposit              5092.361453
# Cash Withdrawal           4696.201203
# International Transfer    8649.275693
# Loan Repayment            5959.343900
# Local Transfer            5475.346314
# Wallet Top-up             8825.631597
# Name: transaction_amount_myr, dtype: float64

# %%
df["balance_change"] = (df["balance_after_myr"] - df["balance_before_myr"])

# %%
df[["balance_before_myr","transaction_amount_myr","balance_after_myr","balance_change"]].head()
# Out:
#    balance_before_myr  transaction_amount_myr  balance_after_myr  \
# 0            25020.79                  764.30           25785.09
# 1             5375.93                 2214.59            3161.34
# 2            12742.00                  710.49           13452.49
# 3            17464.30                 1630.74           19095.04
# 4             3995.31                 1644.29            5639.60
#
#    balance_change
# 0          764.30
# 1        -2214.59
# 2          710.49
# 3         1630.74
# 4         1644.29
